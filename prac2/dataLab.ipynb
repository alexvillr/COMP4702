# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %% [markdown]
# # import dataset and show information

# %%
df = pd.read_csv("./seedlings.csv")

# %%
df.isnull().sum()
# Out:
# Spec           0
# Harv           0
# Block          0
# Trmt           0
# K              0
# Mg             0
# Height         1
# Diameter       1
# N_leaves       1
# Leaf Area     65
# N_branches     1
# DM_leaves      1
# DM_stem        2
# DM_roots       2
# DM_total       2
# Shock          2
# P_conc_L      10
# N_conc_L      10
# Ca_conc_L     10
# K_conc_L      10
# Mg_conc_L     10
# dtype: int64

# %%
dfDropped = df.dropna()

# %%
dfDropped.isnull().sum()
# Out:
# Spec          0
# Harv          0
# Block         0
# Trmt          0
# K             0
# Mg            0
# Height        0
# Diameter      0
# N_leaves      0
# Leaf Area     0
# N_branches    0
# DM_leaves     0
# DM_stem       0
# DM_roots      0
# DM_total      0
# Shock         0
# P_conc_L      0
# N_conc_L      0
# Ca_conc_L     0
# K_conc_L      0
# Mg_conc_L     0
# dtype: int64

# %%
imputer = SimpleImputer(missing_values=pd.NA, strategy='mean')
dfImputed = df.drop(columns='Spec')
imputer.fit(dfImputed)
dfImputed = pd.DataFrame(imputer.transform(dfImputed))
print(dfImputed.info())
dfImputed.to_csv("./imputed_seedlings.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       192 non-null    float64
#  1   1       192 non-null    float64
#  2   2       192 non-null    float64
#  3   3       192 non-null    float64
#  4   4       192 non-null    float64
#  5   5       192 non-null    float64
#  6   6       192 non-null    float64
#  7   7       192 non-null    float64
#  8   8       192 non-null    float64
#  9   9       192 non-null    float64
#  10  10      192 non-null    float64
#  11  11      192 non-null    float64
#  12  12      192 non-null    float64
#  13  13      192 non-null    float64
#  14  14      192 non-null    float64
#  15  15      192 non-null    float64
#  16  16      192 non-null    float64
#  17  17      192 non-null    float64
#  18  18      192 non-null    float64
#  19  19      192 non-null    float64
# dtypes: float64(20)
# ...

# %%
sb.pairplot(dfDropped[['DM_stem', 'DM_total', 'DM_roots', 'Shock', 'Leaf Area']])
sb.pairplot(dfImputed[[12, 14, 13, 15, 8]])
sb.pairplot(df[['DM_stem', 'DM_total', 'DM_roots', 'Shock', 'Leaf Area']])
